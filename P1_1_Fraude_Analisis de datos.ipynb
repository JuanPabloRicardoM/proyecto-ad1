# %% [markdown]
# # 📊 Análisis Univariado & Análisis Bivariado 🔍

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # **Proyecto - Metodología para la detección de fraude en productos de microcrédito de un Banco**.
# 1.	Descripción del problema.
#
# El Banco cuenta con un aplicativo para la detección de fraude en los productos de crédito, sin embargo, las alertas de fraude están configuradas a través de reglas de monitoreo que trabajan de manera independiente, su análisis y toma de decisiones depende de un alto grado de juicio profesional, situación que afecta la oportunidad en la detección de fraudes y puede generar ineficiencias operativas por falsas alertas, en promedio se detectan 6 meses posterior a su materialización y/o cuando el personal del Banco que cometió el fraude se retira. Esta situación impacta negativamente en la eficiencia operativa del área de auditoría, la reputación institucional y la utilidad del Banco.
#
# 2. Justificación del uso de Ciencia de Datos o IA.
#
# La ciencia de datos y la inteligencia artificial permiten optimizar los procesos de detección de fraude mediante el análisis automatizado de grandes volúmenes de datos. A través de un modelo de clasificación, es posible integrar múltiples variables como la ubicación geográfica, comportamiento de pago, comportamiento crediticio en otros bancos, inconsistencias en la información del cliente y similitud con información de colaboradores del banco, permitiendo identificar correlaciones que no son fácilmente detectables a través de reglas independientes y asiladas. Esto permite generar alertas más precisas, reducir falsos positivos, priorizar investigaciones y tomar decisiones oportunas, optimizando recursos operativos y mitigando riesgos reputacionales, financieros y legales.
#
# El modelo planteado para el desrrollo del proyecto es clasificación.
#
# 3.	Formulación de una pregunta SMART.
#
# ¿Cuál es la probabilidad de que un crédito desembolsado presente indicios de fraude en los 30 días posteriores al desembolso, considerando variables como incumplimiento de pago, ciudad de alto riesgo, nivel de mora, valor de desembolso, concentración por analista, inconsistencias en la información del cliente, similitudes con datos de empleados del banco, comportamiento atípico de pagos de clientes de un mismo analista, utilizando un modelo de clasificación basado en datos históricos?
#
#
# # Análisis Exploratoria de los Datos del Banco.
# Las bases de datos utilizdas en el proyecto se encuentra en formato .xls y se encuentran anonimizados. Las bases de datos son:
# 1. Saldo_cartera_jun2025: contiene la información de los saldos de cartera por cliente y crédito al corte 30 junio 2025. Adicionalmente, contiene información general del cliente cómo dirección de residencia, número de télefono, dirección laboral, correo electrónico, entre otros y la información del crédito cómo  calificación de la cartera, días de mora, valor de desembolso, oficina y analista que desembolso, entre otros. El detalle de la información del reporte se encuentra en el "Diccionario de Datos".
#
#
#
#
# ---

# %% [markdown]
# # Analisis de datos base "Saldo_cartera_jun2025"
# - Tipos de datos: la base de datos contiene datos estructurados, contiene ## columnas con información de los créditos y clientes. La información fue anonimizada por la Gerencia de Oficina de Datos, lineamiento procedimental del Banco para la extracción y procesamiento de datos en Python y aplicativos externos.
# - Almacenes de datos: la base de datos se encuentra en formato xls, generado del core bancario y anonimizado. La base de datos cuenta el un número de identificación único para cada cliente, al igual que un único número para cada crédito.
# - Desarrollo de modelos: se desarrollará bajo machine learning.

# %% [markdown]
# # Limpieza de datos.
# La base de datos contiene xxxxxxxxx, razón por la cual, se realizó los siguientes procesos de limpieza:
# 1. Eliminiación de las columnas xxxxx, xxx, xxxx, debido a ...
# 2. Completar xxxxx
# 3. NNNN números o código interno de identificación de analistas se encontraba registrado a más de un analista, razón por la cual se elimino la base, definiendo como identificador de analista el código alfabetico que es único por analista.

# %%
## Identificación de número de columnas y filas en la base de datos

# %%
## Entendimiento del tipo de varibales

# %%
## Identificación de variables duplicadas.

# %%
# Identificación de valores pérdidos, entendimiento del motivo de valores perdidos y definición de tratamiento (remplazo por media, mediana, moda)

# %%
# Errores de digitación y corrección

# %%
# Identificación de valores inconsistentes

# %%
## Eliminación de columnas no requeridas

# %%
# Creación de nuevas variables
